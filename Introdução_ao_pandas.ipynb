# %% [markdown]
# Series
#
# Uma Series é um objeto de tipo array unidimensional que contém uma
# sequência de valores (de tipos semelhantes aos tipos do NumPy) de mesmo
# tipo e um array associado com rótulos de dados chamado índice

# %%
import pandas as pd
import numpy as np

# %%
#declarando uma Series
obj =pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %% [markdown]
# Atributos de Series

# %%
#atributos
obj.array
# Out:
# <NumpyExtensionArray>
# [np.int64(4), np.int64(7), np.int64(-5), np.int64(3)]
# Length: 4, dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Series com rótulos
obj2 = pd.Series([4,7,-5,3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2["a"]
# Out:
# np.int64(-5)

# %%
obj2[obj2 > 0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
import numpy as np
np.exp(obj2)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
"b" in obj2
# Out:
# True

# %%
"e" in obj2
# Out:
# False

# %%
#Criando uma serie pelo dicionario
sdata = {"Ohio":3500, "Texas":7100, "Oregon":1600, "Utah":5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      3500
# Texas     7100
# Oregon    1600
# Utah      5000
# dtype: int64

# %%
#Conversão de serie em dicionario
obj3.to_dict()
# Out:
# {'Ohio': 3500, 'Texas': 7100, 'Oregon': 1600, 'Utah': 5000}

# %%
#sobre escrevedno Keys do dicionario
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California       NaN
# Ohio          3500.0
# Oregon        1600.0
# Texas         7100.0
# dtype: float64

# %%
#valores ausestes,nulos
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
#alinhamento automático pelo rótulo do índice em aritméticas
obj3 + obj4
# Out:
# California        NaN
# Ohio           7000.0
# Oregon         3200.0
# Texas         14200.0
# Utah              NaN
# dtype: float64

# %%
#colocando nome na coluna
obj4.name = "population"
obj4.index.name = "state"
obj4
# Out:
# state
# California       NaN
# Ohio          3500.0
# Oregon        1600.0
# Texas         7100.0
# Name: population, dtype: float64

# %%
#indice por atribuição
obj
obj.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# Data Frame
#
# Um DataFrame representa uma tabela de dados retangular e contém uma
# coleção ordenada e nomeada de colunas, cada uma podendo ter um tipo de
# valor diferente (numérico, string, booleano etc.).

# %%
#criando um dara frame atras de um dicionario de listas
data = {"state":["Ohio","Ohio", "Ohio","Nevada", "Nevada", "Nevada"],
        "year":[2000,2001,2002,2001, 2002, 2003],
        "pop": [1.5,1.7,3.6,2.4,2.9,3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# mostra incio e fim
x =frame.head()
print(x)
print("_______")
y = frame.tail()
print(y)
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# _______
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
#colunas especificadas
pd.DataFrame(data, columns=["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
#recuperação de series uma coluna dataframe
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
#acesso a atributos
frame2.loc[1] #eixo
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2] #inteiros
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
#atribuição
frame2["debt"] = 16.5
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
frame2["eastern"] = frame2["state"] == "Ohio"
frame2
# Out:
#    year   state  pop  debt  eastern
# 0  2000    Ohio  1.5  16.5     True
# 1  2001    Ohio  1.7  16.5     True
# 2  2002    Ohio  3.6  16.5     True
# 3  2001  Nevada  2.4  16.5    False
# 4  2002  Nevada  2.9  16.5    False
# 5  2003  Nevada  3.2  16.5    False

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},
               "Nevada": {2001: 2.4, 2002: 2.9}}
populations
# Out:
# {'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}, 'Nevada': {2001: 2.4, 2002: 2.9}}

# %%
frame3 = pd.DataFrame(populations)
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
#transposição, troca linhas e colunas
frame3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
#retorno bidimensional
frame3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %% [markdown]
# Objetos Index
#
# Os objetos Index do pandas são responsáveis por conter os rótulos dos eixos
# (incluindo o nome das colunas de um DataFrame) e outros metadados (como
# o nome ou os nomes dos eixos).

# %%
from numpy._core.defchararray import index
obj = pd.Series(np.arange(3), index=["a", "b", "c"])
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
index = obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
#objetos index são imutaveis
index[1] =  'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/1309675497.py in <cell line: 0>()
#       1 #objetos index são imutaveis
# ----> 2 index[1] =  'd'
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5369     @final
#    5370     def __setitem__(self, key, value) -> None:
# -> 5371         raise TypeError("Index does not support mutable operations")
#    5372
#    5373     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# Reindexação

# %%
#reindex novo objetos com valores organizados
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=["d", "b","a","c"])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(["a", "b", "c", "d", "e"])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
#metodo method no reindex para preechimento
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(np.arange(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=["a", "c", "d"],
                     columns=["Ohio", "Texas", "California"])

frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
states = ["Texas", "Utah", "California"]
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %% [markdown]
# Remoção de entradas de um eixo

# %%
obj = pd.Series(np.arange(5.), index=["a", "b", "c", "d", "e"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
#reitar c
new_obj = obj.drop("c")
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                   index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
#drop linhas
data.drop(index=["Colorado", "Ohio"])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
#drop colunas
data.drop(columns=["two"])
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
#drop colunas pasando axis=1
data.drop("two", axis=1)
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %% [markdown]
# Indexação, seleção e filtragem

# %%
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b"]
# Out:
# np.float64(1.0)

# %%
obj[1]
# Out:
# /tmp/ipykernel_7534/2469632899.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[1]
# np.float64(1.0)

# %%
obj[2:4]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data["two"]
# Out:
# Ohio         1
# Colorado     5
# Utah         9
# New York    13
# Name: two, dtype: int64

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# New York  False  False  False  False
